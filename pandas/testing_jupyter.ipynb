# %%
import os, pandas as pd

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'commercesparis.csv',
#  'data',
#  'script1.py',
#  'testing_jupyter.ipynb']

# %%
os.listdir("./data")
# Out:
# ['supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  '~$supermarkets.xlsx']

# %%
df_csv = pd.read_csv("./data/supermarkets.csv")
df_csv
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df_csv.shape
# Out:
# (7, 7)

# %%
df_csv.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df_csv.where(df_csv.State == "California")
# Out:
#     ID          Address           City       State Country     Name  Employees
# 0  NaN              NaN            NaN         NaN     NaN      NaN        NaN
# 1  NaN              NaN            NaN         NaN     NaN      NaN        NaN
# 2  NaN              NaN            NaN         NaN     NaN      NaN        NaN
# 3  NaN              NaN            NaN         NaN     NaN      NaN        NaN
# 4  5.0  1056 Sanchez St  San Francisco  California     USA  Sanchez       12.0
# 5  NaN              NaN            NaN         NaN     NaN      NaN        NaN

# %%
df_json = pd.read_json("./data/supermarkets.json")
df_json
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
type(df_json)
# Out:
# pandas.core.frame.DataFrame

# %%
import xlrd
df_xlsx = pd.read_excel("./data/supermarkets.xlsx", sheetname = 0)
df_xlsx
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df_txt = pd.read_csv("./data/supermarkets-commas.txt")
df_txt
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df = pd.read_csv("./data/supermarkets-semi-colons.txt", sep=",")
df
# Out:
#         ID;Address;City;State;Country;Name;Employees
# 0  1;3666 21st St;San Francisco;CA 94114;USA;Made...
# 1  2;735 Dolores St;San Francisco;CA 94119;USA;Br...
# 2  3;332 Hill St;San Francisco;California 94114;U...
# 3  4;3995 23rd St;San Francisco;CA 94114;USA;Ben'...
# 4  5;1056 Sanchez St;San Francisco;California;USA...
# 5  6;551 Alvarado St;San Francisco;CA 94114;USA;R...

# %%
df2 = pd.read_csv("./data/supermarkets-semi-colons.txt", sep=";")
df2
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'commercesparis.csv',
#  'data',
#  'script1.py',
#  'testing_jupyter.ipynb']

# %%
test = pd.read_csv("./commercesparis.csv", sep=";")
test
# Out:
#          ORDRE  ARRONDISSEMENT  QUARTIER       IRIS         ILOT  NUMERO  LET  \
# 0      36901.0           75011      42.0  751114202  75111420031   108.0  NaN
# 1      36902.0           75011      42.0  751114202  75111420031   108.0  NaN
# 2      36903.0           75011      42.0  751114202  75111420031   110.0  NaN
# 3      36913.0           75011      42.0  751114202  75111420031    48.0  NaN
# 4      36917.0           75011      42.0  751114203  75111420032   109.0  NaN
# 5      36922.0           75011      42.0  751114203  75111420032   115.0  NaN
# 6      36923.0           75011      42.0  751114203  75111420032   115.0  NaN
# 7      36925.0           75011      42.0  751114203  75111420032    42.0  NaN
# 8      36933.0           75011      42.0  751114203  75111420032    51.0  NaN
# 9      36938.0           75011      42.0  751114203  75111420033    12.0  NaN
# 10     36951.0           75011      42.0  751114203  75111420033    65.0  NaN
# ...

# %%
df3 = pd.read_csv("http://pythonhow.com/supermarkets.csv")
df3
# Out:
#    ID          Address            City             State Country  \
# 0   1     3666 21st St   San Francisco          CA 94114     USA
# 1   2   735 Dolores St   San Francisco          CA 94119     USA
# 2   3      332 Hill St   San Francisco  California 94114     USA
# 3   4     3995 23rd St   San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St   San Francisco        California     USA
# 5   6  551 Alvarado St   San Francisco          CA 94114     USA
#
#            Name  Employees
# 0       Madeira          8
# 1   Bready Shop         15
# 2   Super River         25
# 3    Ben's Shop         10
# 4       Sanchez         12
# 5    Richvalley         20
